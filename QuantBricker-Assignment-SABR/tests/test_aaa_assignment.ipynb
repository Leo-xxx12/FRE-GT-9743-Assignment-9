# %%
pip install construct
# Out:
# Requirement already satisfied: construct in /opt/anaconda3/lib/python3.13/site-packages (2.10.70)
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys, os
repo_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if repo_root not in sys.path:
    sys.path.insert(0, repo_root)
print("Added to sys.path:", repo_root)
from fixedincomelib import *
print("Fixed Income Library is loaded.")
# Out:
# Added to sys.path: /Users/leo/Leo/Risk_topic/FRE-GT-9743-Assignment-9/QuantBricker-Assignment-SABR
# Fixed Income Library is loaded.

# %% [markdown]
# ### Build yield curve sub model

# %%
path = "serialized/yc_model_calibrated.pickle"
yc_model = qfReadModelFromFile(path)
yc_model.components_.keys()
# Out:
# dict_keys(['SOFR-1B-FLAT', 'SOFRON Actual/360'])

# %% [markdown]
# ### Create Build Method Collection

# %%
build_method_type = 'IR_SABR'
content = {
    'TARGET' : 'SOFR-1B-SWAPTION',
    'SWAPTION NORMAL VOLATILITY' : 'USD-SOFR-SWAPTION',
    'SWAPTION SABR BETA' : 'USD-SOFR-SWAPTION',
    'SWAPTION SABR NU' : 'USD-SOFR-SWAPTION',
    'SWAPTION SABR RHO' : 'USD-SOFR-SWAPTION',
    'VOL INTERPOLATION DOMAIN' : 'NORMAL VOLATILITY',
    'INTERPOLATION METHOD' : 'LINEAR',
    'EXTRAPOLATION METHOD' : 'FLAT',
    'BUSINESSDAY CONVENTION' : 'F',
    'HOLIDAY CONVENTION' : 'USGS',
    'SHIFT' : 0.04
}
sabr_build_method = qfCreateBuildMethod(build_method_type, content)
display(sabr_build_method.display())
# Out:
#                           Name              Value
# 0                       TARGET   SOFR-1B-SWAPTION
# 1   SWAPTION NORMAL VOLATILITY  USD-SOFR-SWAPTION
# 2           SWAPTION SABR BETA  USD-SOFR-SWAPTION
# 3             SWAPTION SABR NU  USD-SOFR-SWAPTION
# 4            SWAPTION SABR RHO  USD-SOFR-SWAPTION
# 5     VOL INTERPOLATION DOMAIN  NORMAL VOLATILITY
# 6         INTERPOLATION METHOD             LINEAR
# 7         EXTRAPOLATION METHOD               FLAT
# 8       BUSINESSDAY CONVENTION                  F
# 9           HOLIDAY CONVENTION               USGS
# 10                       SHIFT               0.04

# %%
### serialize / de-serialize
path = 'sabr_build_method.pickle'
qfWriteBuildMethodToFile(sabr_build_method, path)
display(sabr_build_method.display())
sabr_build_method_back = qfReadBuildMethodFromFile(path)
# check
display(sabr_build_method_back.display())
# house keeping
os.remove(path)
# Out:
#                           Name              Value
# 0                       TARGET   SOFR-1B-SWAPTION
# 1   SWAPTION NORMAL VOLATILITY  USD-SOFR-SWAPTION
# 2           SWAPTION SABR BETA  USD-SOFR-SWAPTION
# 3             SWAPTION SABR NU  USD-SOFR-SWAPTION
# 4            SWAPTION SABR RHO  USD-SOFR-SWAPTION
# 5     VOL INTERPOLATION DOMAIN  NORMAL VOLATILITY
# 6         INTERPOLATION METHOD             LINEAR
# 7         EXTRAPOLATION METHOD               FLAT
# 8       BUSINESSDAY CONVENTION                  F
# 9           HOLIDAY CONVENTION               USGS
# 10                       SHIFT               0.04
#                           Name              Value
# 0   SWAPTION NORMAL VOLATILITY  USD-SOFR-SWAPTION
# 1                        SHIFT               0.04
# 2           SWAPTION SABR BETA  USD-SOFR-SWAPTION
# 3         INTERPOLATION METHOD             LINEAR
# 4     VOL INTERPOLATION DOMAIN  NORMAL VOLATILITY
# 5           HOLIDAY CONVENTION               USGS
# 6       BUSINESSDAY CONVENTION                  F
# 7             SWAPTION SABR NU  USD-SOFR-SWAPTION
# 8         EXTRAPOLATION METHOD               FLAT
# 9            SWAPTION SABR RHO  USD-SOFR-SWAPTION
# 10                      TARGET   SOFR-1B-SWAPTION

# %%
### caplet
build_method_type = 'IR_SABR'
content_cf = {
    'TARGET' : 'SOFR-1B-CAPFLOOR',
    'SWAPTION NORMAL VOLATILITY' : 'USD-SOFR-CAPFLOOR',
    'SWAPTION SABR BETA' : 'USD-SOFR-CAPFLOOR',
    'SWAPTION SABR NU' : 'USD-SOFR-CAPFLOOR',
    'SWAPTION SABR RHO' : 'USD-SOFR-CAPFLOOR',
    'VOL INTERPOLATION DOMAIN' : 'NORMAL VOLATILITY',
    'INTERPOLATION METHOD' : 'LINEAR',
    'EXTRAPOLATION METHOD' : 'FLAT',
    'BUSINESSDAY CONVENTION' : 'F',
    'HOLIDAY CONVENTION' : 'USGS',
    'SHIFT' : 0.04
}
sabr_build_method_cf = qfCreateBuildMethod(build_method_type, content_cf)
display(sabr_build_method_cf.display())
# Out:
#                           Name              Value
# 0                       TARGET   SOFR-1B-CAPFLOOR
# 1   SWAPTION NORMAL VOLATILITY  USD-SOFR-CAPFLOOR
# 2           SWAPTION SABR BETA  USD-SOFR-CAPFLOOR
# 3             SWAPTION SABR NU  USD-SOFR-CAPFLOOR
# 4            SWAPTION SABR RHO  USD-SOFR-CAPFLOOR
# 5     VOL INTERPOLATION DOMAIN  NORMAL VOLATILITY
# 6         INTERPOLATION METHOD             LINEAR
# 7         EXTRAPOLATION METHOD               FLAT
# 8       BUSINESSDAY CONVENTION                  F
# 9           HOLIDAY CONVENTION               USGS
# 10                       SHIFT               0.04

# %%
### pack up as build method collection
bm_list = [sabr_build_method, sabr_build_method_cf]
bm_collection = qfCreateModelBuildMethodCollection(bm_list)
bm_collection.display()
# Out:
#       Name             Value
# 0  IR_SABR  SOFR-1B-SWAPTION
# 1  IR_SABR  SOFR-1B-CAPFLOOR

# %% [markdown]
# ### Data Collection

# %%
### swaption
expiries = ['3M', '6M', '1Y', '5Y', '10Y']
tenors = ['1Y', '5Y', '10Y']
data_conv = 'USD-SOFR-SWAPTION'
# nv
df = pd.DataFrame(np.random.uniform(low=90./1e4, high=110./1e4, size=(len(expiries), len(tenors))), index=expiries, columns=tenors)
data2D_nv = qfCreateData2D('Swaption Normal Volatility', data_conv, df)
# beta
df = pd.DataFrame(np.random.uniform(low=60./1e2, high=60./1e2, size=(len(expiries), len(tenors))), index=expiries, columns=tenors)
data2D_beta = qfCreateData2D('Swaption SABR Beta', data_conv, df)
# nu
df = pd.DataFrame(np.random.uniform(low=0.01, high=0.3, size=(len(expiries), len(tenors))), index=expiries, columns=tenors)
data2D_nu= qfCreateData2D('Swaption SABR Nu', data_conv, df)
# rho
df = pd.DataFrame(np.random.uniform(low=-0.99, high=0.99, size=(len(expiries), len(tenors))), index=expiries, columns=tenors)
data2D_rho = qfCreateData2D('Swaption SABR Rho', data_conv, df)

# %%
### capfloor
expiries = ['3M', '6M', '1Y', '5Y', '10Y']
tenors = ['1M', '3M', '6M']
data_conv = 'USD-SOFR-CAPFLOOR'
# nv
df = pd.DataFrame(np.random.uniform(low=90./1e4, high=110./1e4, size=(len(expiries), len(tenors))), index=expiries, columns=tenors)
data2D_nv_cf = qfCreateData2D('Swaption Normal Volatility', data_conv, df)
# beta
df = pd.DataFrame(np.random.uniform(low=60./1e2, high=60./1e2, size=(len(expiries), len(tenors))), index=expiries, columns=tenors)
data2D_beta_cf = qfCreateData2D('Swaption SABR Beta', data_conv, df)
# nu
df = pd.DataFrame(np.random.uniform(low=0.01, high=0.3, size=(len(expiries), len(tenors))), index=expiries, columns=tenors)
data2D_nu_cf= qfCreateData2D('Swaption SABR Nu', data_conv, df)
# rho
df = pd.DataFrame(np.random.uniform(low=-0.99, high=0.99, size=(len(expiries), len(tenors))), index=expiries, columns=tenors)
data2D_rho_cf = qfCreateData2D('Swaption SABR Rho', data_conv, df)

# %%
### create a data collection
data_list = [
    data2D_nv, data2D_beta, data2D_nu, data2D_rho,
    data2D_nv_cf, data2D_beta_cf, data2D_nu_cf, data2D_rho_cf]
data_collection = qfCreateDataCollection(data_list)
display(data_collection.display())
# Out:
#   Data Shape                   Data Type    Data Convention
# 0     DATA2D  Swaption Normal Volatility  USD-SOFR-SWAPTION
# 1     DATA2D          Swaption SABR Beta  USD-SOFR-SWAPTION
# 2     DATA2D            Swaption SABR Nu  USD-SOFR-SWAPTION
# 3     DATA2D           Swaption SABR Rho  USD-SOFR-SWAPTION
# 4     DATA2D  Swaption Normal Volatility  USD-SOFR-CAPFLOOR
# 5     DATA2D          Swaption SABR Beta  USD-SOFR-CAPFLOOR
# 6     DATA2D            Swaption SABR Nu  USD-SOFR-CAPFLOOR
# 7     DATA2D           Swaption SABR Rho  USD-SOFR-CAPFLOOR

# %% [markdown]
# ### Create product and display

# %%
caplet = qfCreateProductRFRCapletFloorlet(
    effective_date="2026-06-17",
    expiry_offset="0D",
    term_or_termination_date="3M",
    payment_date="2026-09-21",
    on_index="SOFR-1B",
    strike=0.045,
    cap_or_floor="CAP",
    notional=1_000_000,
    accrual_basis="ACT/360",
    long_or_short="LONG",
)

qfDisplayProduct(caplet)
# Out:
#                 Name                        Value
# 0       Product Type  PRODUCT_RFR_CAPLET_FLOORLET
# 1           Notional                      1000000
# 2           Currency                          USD
# 3      Long Or Short                         LONG
# 4     Effective Date                   2026-06-17
# 5      Expiry Offset                           0D
# 6        Expiry Date                   2026-06-17
# 7   Termination Date                   2026-09-17
# 8       Payment Date                   2026-09-21
# 9           ON Index            SOFRON Actual/360
# 10            Strike                        0.045
# 11      Cap Or Floor                          CAP
# 12     Accrual Basis                      ACT/360
# 13           Accrual                     0.255556

# %%
from fixedincomelib.date import make_schedule, Date, Period
from fixedincomelib.market.basics import AccrualBasis, BusinessDayConvention, HolidayConvention

sched = make_schedule(
    start_date=Date("2026-06-17"),
    end_date=Date("2028-06-17"),
    accrual_period=Period("3M"),
    holiday_convention=HolidayConvention("USGS"),
    business_day_convention=BusinessDayConvention("MF"),
    accrual_basis=AccrualBasis("ACT/360"),
    payment_offset=Period("2D"),
    payment_business_day_convention=BusinessDayConvention("F"),
    payment_holiday_convention=HolidayConvention("USGS"),
)
print(sched.columns.tolist())
print(sched.head(2))
# Out:
# ['StartDate', 'EndDate', 'FixingDate', 'PaymentDate', 'Accrued']
#               StartDate               EndDate            FixingDate  \
# 0       June 17th, 2026  September 17th, 2026       June 17th, 2026
# 1  September 17th, 2026   December 17th, 2026  September 17th, 2026
#
#             PaymentDate   Accrued
# 0  September 21st, 2026  0.255556
# 1   December 21st, 2026  0.252778

# %%
# Please complete the product-related implementation in non_linear_products, product_factory, product_display_visitor, and the product-related API.
cap = qfCreateProductRFRCapFloor(
    effective_date="2026-06-17",
    term_or_termination_date="2Y",
    on_index="SOFR-1B",
    strike=0.045,
    cap_or_floor="CAP",
    notional=1_000_000,
    accrual_period="3M",
    accrual_basis="ACT/360",
    payment_offset="2D",
    payment_business_day_convention="F",
    payment_holiday_convention="USGS",
    long_or_short="LONG",
    business_day_convention="MF",
    holiday_convention="USGS",
)

qfDisplayProduct(cap)
# Out:
#                 Name                  Value
# 0       Product Type  PRODUCT_RFR_CAP_FLOOR
# 1           Notional                1000000
# 2           Currency                    USD
# 3      Long Or Short                   LONG
# 4     Effective Date             2026-06-17
# 5   Termination Date             2028-06-20
# 6           ON Index      SOFRON Actual/360
# 7             Strike                  0.045
# 8       Cap Or Floor                    CAP
# 9     Accrual Period                     3M
# 10     Accrual Basis                ACT/360
# 11    Payment Offset                     2D
# 12       Payment BDC                      F
# 13   Payment Holiday                   USGS
# 14       Num Caplets                      9

# %% [markdown]
# ### Create sabr model

# %%
sabr_model = qfCreateSABRModel(
    sub_model=yc_model,
    data_collection=data_collection,
    build_method_collection=bm_collection
)
print("SABR components:", sabr_model.components_.keys())
# Out:
# SABR components: dict_keys(['SOFR-1B-SWAPTION', 'SOFR-1B-CAPFLOOR'])

# %%
# in notebook, after building sabr_model
comp = sabr_model.retrieve_model_component(IndexRegistry().get("SOFR-1B-CAPFLOOR"))
interp = comp.interpolator_[SABRParameters.NV]
print(type(interp))
print([m for m in dir(interp) if not m.startswith('_')])
# Out:
# <class 'fixedincomelib.utilities.numerics.Interpolator2DLinearFlat'>
# ['axis1', 'axis1_', 'axis2', 'axis2_', 'extrap_method', 'extrap_method_', 'gradient_wrt_ordinate', 'interp_method', 'interp_method_', 'interpolate', 'size1', 'size1_', 'size2', 'size2_', 'values', 'values_']

# %%
# You should complete SABRModelComponent.get_sabr_parameters and SABRModelComponent.get_sabr_parameter_gradient_wrt_state.
sabr_model.get_sabr_parameters(IndexRegistry().get("SOFR-1B-CAPFLOOR"), 0.5, 0.25)
# Out:
# {<SABRParameters.NV: 'SWAPTION NORMAL VOLATILITY'>: 0.010786536169437158,
#  <SABRParameters.BETA: 'SWAPTION SABR BETA'>: 0.6,
#  <SABRParameters.NU: 'SWAPTION SABR NU'>: 0.26345023351265234,
#  <SABRParameters.RHO: 'SWAPTION SABR RHO'>: 0.6124873444614524}

# %%
vp_funding = FundingIndexParameter({"Funding Index": "SOFR-1B-FLAT"})
vpc = ValuationParametersCollection([vp_funding])
request = ValuationRequest.PV

# %% [markdown]
# ### Price caplet
# I provide the cap results here as a reference, so you can see what the expected output should look like.

# %%
ve_caplet = ValuationEngineRFRCapletFloorlet(
    sabr_model,
    vpc,
    caplet,
    request,
)

ve_caplet.calculate_value()

print("PV            :", ve_caplet.value_)
print("Cash          :", ve_caplet.cash_)
print("NV/BETA/NU/RHO:", ve_caplet.sabr_result_.get(SABRParameters.NV), ve_caplet.sabr_result_.get(SABRParameters.BETA), ve_caplet.sabr_result_.get(SABRParameters.NU), ve_caplet.sabr_result_.get(SABRParameters.RHO))
print("Option Value  :", ve_caplet.option_value_)
# Out:
# PV            : 38.94613575493358
# Cash          : 0.0
# NV/BETA/NU/RHO: 0.010811929571626737 0.6 0.23412938264960464 0.8000956762263203
# Option Value  : 0.0001556567895031804

# %%
pv_cash_report = ve_caplet.get_value_and_cash()
display(pv_cash_report.display())
# Out:
#   Currency  Type      Value
# 0      USD    PV  38.946136
# 1      USD  CASH   0.000000

# %%
cf_report = ve_caplet.create_cash_flows_report()
display(cf_report.display())
# Out:
#                   PRODUCT_TYPE             VALUATION_ENGINE_TYPE  LEG_ID  \
# 0  PRODUCT_RFR_CAPLET_FLOORLET  ValuationEngineRFRCapletFloorlet       0
#
#    CASHFLOW_ID  PAY_OR_RECEIVE  NOTIONAL              PAY_DATE  \
# 0            0             1.0   1000000  September 21st, 2026
#
#    FORECASTED_AMOUNT         PV  DISCOUNG FACTOR      FIXING_DATE  \
# 0          39.778957  38.946136         0.979064  June 17th, 2026
#
#         START_DATE              END_DATE   ACCRUED     INDEX_OR_FIXED  \
# 0  June 17th, 2026  September 17th, 2026  0.255556  SOFRON Actual/360
#
#    INDEX_VALUE
# 0      0.03303

# %%
### test risk
df_risk = qfCreateValueReport(sabr_model, caplet, vpc, 'firstorderrisk').display()
df_risk[np.abs(df_risk["VALUES"].astype(float)) > 1e-10]
# Out:
#                       DATA_TYPE    DATA_CONVENTION                  AXIS1  \
# 5        OVERNIGHT INDEX FUTURE     SOFR-FUTURE-3M  2026-03-19x2026-06-18
# 6        OVERNIGHT INDEX FUTURE     SOFR-FUTURE-3M  2026-06-18x2026-09-17
# 94   SWAPTION NORMAL VOLATILITY  USD-SOFR-CAPFLOOR                     3M
# 95   SWAPTION NORMAL VOLATILITY  USD-SOFR-CAPFLOOR                     3M
# 97   SWAPTION NORMAL VOLATILITY  USD-SOFR-CAPFLOOR                     6M
# 98   SWAPTION NORMAL VOLATILITY  USD-SOFR-CAPFLOOR                     6M
# 109          SWAPTION SABR BETA  USD-SOFR-CAPFLOOR                     3M
# 110          SWAPTION SABR BETA  USD-SOFR-CAPFLOOR                     3M
# 112          SWAPTION SABR BETA  USD-SOFR-CAPFLOOR                     6M
# 113          SWAPTION SABR BETA  USD-SOFR-CAPFLOOR                     6M
# 124            SWAPTION SABR NU  USD-SOFR-CAPFLOOR                     3M
# 125            SWAPTION SABR NU  USD-SOFR-CAPFLOOR                     3M
# 127            SWAPTION SABR NU  USD-SOFR-CAPFLOOR                     6M
# 128            SWAPTION SABR NU  USD-SOFR-CAPFLOOR                     6M
# 139           SWAPTION SABR RHO  USD-SOFR-CAPFLOOR                     3M
# 140           SWAPTION SABR RHO  USD-SOFR-CAPFLOOR                     3M
# 142           SWAPTION SABR RHO  USD-SOFR-CAPFLOOR                     6M
# 143           SWAPTION SABR RHO  USD-SOFR-CAPFLOOR                     6M
#
#     AXIS2 MARKET_QUOTE   UNIT       VALUES
# 5                96.44  -0.01     0.013005
# 6                 96.7  -0.01     1.184221
# 94     3M     0.010896    1.0  9172.609370
# 95     6M     0.009771    1.0   447.302673
# 97     3M     0.010821    1.0  6170.664485
# 98     6M     0.009595    1.0   300.912708
# 109    3M          0.6    1.0     7.631570
# 110    6M          0.6    1.0     0.372154
# 112    3M          0.6    1.0     5.133965
# 113    6M          0.6    1.0     0.250358
# 124    3M     0.214859    1.0    41.773194
# 125    6M     0.186693    1.0     2.037072
# 127    3M     0.265006    1.0    28.101967
# 128    6M     0.258897    1.0     1.370394
# 139    3M     0.949198    1.0    10.180648
# 140    6M     0.259189    1.0     0.496460
# 142    3M     0.608643    1.0     6.848799
# 143    6M     0.985126    1.0     0.333982

# %%
# Bump Reval
risk_data_type = "SWAPTION NORMAL VOLATILITY"
risk_data_convention = "USD-SOFR-CAPFLOOR"
risk_expiry = "3M"
risk_tenor = "3M"

bump_size = 1e-4
pv_base = qfCreateValueReport(sabr_model, caplet, vpc, "pv")[0][1]

# %%
# Step 1: build bumped up model
df_nv_cf_bumped = data2D_nv_cf.display().copy()
cur_nv = df_nv_cf_bumped.loc[risk_expiry, risk_tenor]
df_nv_cf_bumped.loc[risk_expiry, risk_tenor] = cur_nv + bump_size
data2D_nv_cf_bumped = qfCreateData2D(risk_data_type, risk_data_convention, df_nv_cf_bumped)
data_list_bumped = [data2D_nv, data2D_beta, data2D_nu, data2D_rho,
                    data2D_nv_cf_bumped, data2D_beta_cf, data2D_nu_cf, data2D_rho_cf]
data_collection_bumped = qfCreateDataCollection(data_list_bumped)
sabr_model_bumped = qfCreateSABRModel(sub_model=yc_model,
                                      data_collection= data_collection_bumped,
                                      build_method_collection=bm_collection)

# Step 2: re-value the same product
pv_bumped = qfCreateValueReport(sabr_model_bumped, caplet, vpc, 'pv')[0][1]

# Step 3 : bump-reval risk
risk_bump_reval = pv_bumped - pv_base
print(f'Bump reval risk is {risk_bump_reval:.10f}.')

# Step 4: analytic risk
analytic_risk = df_risk[
    (df_risk["DATA_TYPE"] == risk_data_type)
    & (df_risk["DATA_CONVENTION"] == risk_data_convention)
    & (df_risk["AXIS1"] == risk_expiry)
    & (df_risk["AXIS2"] == risk_tenor)
]['VALUES'].values[0]
analytic_scaled = analytic_risk * bump_size
print(f'Analytic risk is {analytic_scaled}')
print(f"Difference is {risk_bump_reval - analytic_scaled:.10e}.")
# Out:
# Bump reval risk is 0.9231525709.
# Analytic risk is 0.9172609369559188
# Difference is 5.8916339735e-03.

# %% [markdown]
# ### Price CapFloor

# %%
ve_cap = ValuationEngineRFRCapletFloorlet(
    sabr_model,
    vpc,
    cap,
    request,
)

ve_cap.calculate_value()

print("PV            :", ve_cap.value_)
print("Cash          :", ve_cap.cash_)
print("NV/BETA/NU/RHO:", ve_cap.sabr_result_.get(SABRParameters.NV), ve_cap.sabr_result_.get(SABRParameters.BETA), ve_cap.sabr_result_.get(SABRParameters.NU), ve_cap.sabr_result_.get(SABRParameters.RHO))
print("Option Value  :", ve_cap.option_value_)
# Out:
# PV            : 125.33853798142076
# Cash          : 0.0
# NV/BETA/NU/RHO: 0.00969996738523188 0.6 0.21573158087232208 0.5511419729062106
# Option Value  : 6.63875867904667e-05

# %%
pv_cash_report_cap = ve_cap.get_value_and_cash()
display(pv_cash_report_cap.display())
# Out:
#   Currency  Type       Value
# 0      USD    PV  125.338538
# 1      USD  CASH    0.000000

# %%
cf_report_cap = ve_cap.create_cash_flows_report()
display(cf_report_cap.display())
# Out:
#             PRODUCT_TYPE             VALUATION_ENGINE_TYPE  LEG_ID  \
# 0  PRODUCT_RFR_CAP_FLOOR  ValuationEngineRFRCapletFloorlet       0
#
#    CASHFLOW_ID  PAY_OR_RECEIVE  NOTIONAL         PAY_DATE  FORECASTED_AMOUNT  \
# 0            0             1.0   1000000  June 22nd, 2028         135.356913
#
#            PV  DISCOUNG FACTOR      FIXING_DATE       START_DATE  \
# 0  125.338538         0.925985  June 17th, 2026  June 17th, 2026
#
#           END_DATE   ACCRUED     INDEX_OR_FIXED  INDEX_VALUE
# 0  June 20th, 2028  2.038889  SOFRON Actual/360     0.032579

# %%
### test risk
df_risk_cap = qfCreateValueReport(sabr_model, cap, vpc, 'firstorderrisk').display()
df_risk_cap[np.abs(df_risk_cap["VALUES"].astype(float)) > 1e-10]
# Out:
#                       DATA_TYPE    DATA_CONVENTION                  AXIS1  \
# 5        OVERNIGHT INDEX FUTURE     SOFR-FUTURE-3M  2026-03-19x2026-06-18
# 6        OVERNIGHT INDEX FUTURE     SOFR-FUTURE-3M  2026-06-18x2026-09-17
# 7        OVERNIGHT INDEX FUTURE     SOFR-FUTURE-3M  2026-09-17x2026-12-10
# 8        OVERNIGHT INDEX FUTURE     SOFR-FUTURE-3M  2026-12-10x2027-03-17
# 9        OVERNIGHT INDEX FUTURE     SOFR-FUTURE-3M  2027-03-17x2027-06-16
# 10       OVERNIGHT INDEX FUTURE     SOFR-FUTURE-3M  2027-06-16x2027-09-15
# 11       OVERNIGHT INDEX FUTURE     SOFR-FUTURE-3M  2027-09-15x2027-12-15
# 12       OVERNIGHT INDEX FUTURE     SOFR-FUTURE-3M  2027-12-15x2028-03-15
# 13       OVERNIGHT INDEX FUTURE     SOFR-FUTURE-3M  2028-03-15x2028-06-21
# 93   SWAPTION NORMAL VOLATILITY  USD-SOFR-CAPFLOOR                     3M
# 94   SWAPTION NORMAL VOLATILITY  USD-SOFR-CAPFLOOR                     3M
# 95   SWAPTION NORMAL VOLATILITY  USD-SOFR-CAPFLOOR                     3M
# 96   SWAPTION NORMAL VOLATILITY  USD-SOFR-CAPFLOOR                     6M
# 97   SWAPTION NORMAL VOLATILITY  USD-SOFR-CAPFLOOR                     6M
# 98   SWAPTION NORMAL VOLATILITY  USD-SOFR-CAPFLOOR                     6M
# 100  SWAPTION NORMAL VOLATILITY  USD-SOFR-CAPFLOOR                     1Y
# 101  SWAPTION NORMAL VOLATILITY  USD-SOFR-CAPFLOOR                     1Y
# 103  SWAPTION NORMAL VOLATILITY  USD-SOFR-CAPFLOOR                     5Y
# 104  SWAPTION NORMAL VOLATILITY  USD-SOFR-CAPFLOOR                     5Y
# 108          SWAPTION SABR BETA  USD-SOFR-CAPFLOOR                     3M
# 109          SWAPTION SABR BETA  USD-SOFR-CAPFLOOR                     3M
# 110          SWAPTION SABR BETA  USD-SOFR-CAPFLOOR                     3M
# 111          SWAPTION SABR BETA  USD-SOFR-CAPFLOOR                     6M
# 112          SWAPTION SABR BETA  USD-SOFR-CAPFLOOR                     6M
# 113          SWAPTION SABR BETA  USD-SOFR-CAPFLOOR                     6M
# 115          SWAPTION SABR BETA  USD-SOFR-CAPFLOOR                     1Y
# 116          SWAPTION SABR BETA  USD-SOFR-CAPFLOOR                     1Y
# 118          SWAPTION SABR BETA  USD-SOFR-CAPFLOOR                     5Y
# 119          SWAPTION SABR BETA  USD-SOFR-CAPFLOOR                     5Y
# 123            SWAPTION SABR NU  USD-SOFR-CAPFLOOR                     3M
# 124            SWAPTION SABR NU  USD-SOFR-CAPFLOOR                     3M
# 125            SWAPTION SABR NU  USD-SOFR-CAPFLOOR                     3M
# 126            SWAPTION SABR NU  USD-SOFR-CAPFLOOR                     6M
# 127            SWAPTION SABR NU  USD-SOFR-CAPFLOOR                     6M
# 128            SWAPTION SABR NU  USD-SOFR-CAPFLOOR                     6M
# 130            SWAPTION SABR NU  USD-SOFR-CAPFLOOR                     1Y
# 131            SWAPTION SABR NU  USD-SOFR-CAPFLOOR                     1Y
# 133            SWAPTION SABR NU  USD-SOFR-CAPFLOOR                     5Y
# 134            SWAPTION SABR NU  USD-SOFR-CAPFLOOR                     5Y
# 138           SWAPTION SABR RHO  USD-SOFR-CAPFLOOR                     3M
# 139           SWAPTION SABR RHO  USD-SOFR-CAPFLOOR                     3M
# 140           SWAPTION SABR RHO  USD-SOFR-CAPFLOOR                     3M
# 141           SWAPTION SABR RHO  USD-SOFR-CAPFLOOR                     6M
# 142           SWAPTION SABR RHO  USD-SOFR-CAPFLOOR                     6M
# 143           SWAPTION SABR RHO  USD-SOFR-CAPFLOOR                     6M
# 145           SWAPTION SABR RHO  USD-SOFR-CAPFLOOR                     1Y
# 146           SWAPTION SABR RHO  USD-SOFR-CAPFLOOR                     1Y
# 148           SWAPTION SABR RHO  USD-SOFR-CAPFLOOR                     5Y
# 149           SWAPTION SABR RHO  USD-SOFR-CAPFLOOR                     5Y
#
#     AXIS2 MARKET_QUOTE   UNIT         VALUES
# 5                96.44  -0.01       0.005269
# 6                 96.7  -0.01       1.203014
# 7                96.85  -0.01       1.616377
# 8                 96.9  -0.01       2.317792
# 9                96.91  -0.01       2.768989
# 10               96.89  -0.01       3.470560
# 11               96.85  -0.01       4.167142
# 12               96.81  -0.01       4.785413
# 13               96.76  -0.01       5.709861
# 93     1M     0.009725    1.0     214.090458
# 94     3M     0.010896    1.0    8809.531642
# 95     6M     0.009771    1.0     324.031920
# 96     1M      0.00917    1.0     144.024490
# 97     3M     0.010821    1.0   38856.564515
# 98     6M     0.009595    1.0    1429.220952
# 100    3M     0.010237    1.0  339698.973602
# 101    6M     0.009604    1.0   13355.183171
# 103    3M     0.010809    1.0   64276.382439
# 104    6M     0.009917    1.0    2692.006716
# 108    1M          0.6    1.0       0.150877
# 109    3M          0.6    1.0       7.399860
# 110    6M          0.6    1.0       0.272181
# 111    1M          0.6    1.0       0.101499
# 112    3M          0.6    1.0      35.799152
# 113    6M          0.6    1.0       1.316763
# 115    3M          0.6    1.0     303.729732
# 116    6M          0.6    1.0      11.893666
# 118    3M          0.6    1.0      55.796019
# 119    6M          0.6    1.0       2.327316
# 123    1M     0.233817    1.0      -0.447623
# 124    3M     0.214859    1.0      39.955178
# 125    6M     0.186693    1.0       1.469630
# 126    1M     0.205755    1.0      -0.301128
# 127    3M     0.265006    1.0     128.429501
# 128    6M     0.258897    1.0       4.723890
# 130    3M     0.092706    1.0      44.385175
# 131    6M     0.078341    1.0       1.397789
# 133    3M      0.13281    1.0     -10.317223
# 134    6M     0.048388    1.0      -0.468938
# 138    1M     -0.47447    1.0       0.299357
# 139    3M     0.949198    1.0       9.968992
# 140    6M     0.259189    1.0       0.366679
# 141    1M    -0.562468    1.0       0.201386
# 142    3M     0.608643    1.0      44.625585
# 143    6M     0.985126    1.0       1.641417
# 145    3M    -0.022517    1.0     222.980163
# 146    6M    -0.739642    1.0       8.731886
# 148    3M    -0.354258    1.0      39.962842
# 149    6M     0.725728    1.0       1.671924

# %%
# Please write a bump reval test

# %%
risk_data_type = "SWAPTION NORMAL VOLATILITY"
risk_data_convention = "USD-SOFR-CAPFLOOR"
risk_expiry = "3M"
risk_tenor = "3M"

bump_size = 1e-4
pv_base_cap = qfCreateValueReport(sabr_model, cap, vpc, "pv")[0][1]

df_nv_cf_bumped = data2D_nv_cf.display().copy()
cur_nv = df_nv_cf_bumped.loc[risk_expiry, risk_tenor]
df_nv_cf_bumped.loc[risk_expiry, risk_tenor] = cur_nv + bump_size
data2D_nv_cf_bumped = qfCreateData2D(risk_data_type, risk_data_convention, df_nv_cf_bumped)
data_list_bumped = [data2D_nv, data2D_beta, data2D_nu, data2D_rho,
                    data2D_nv_cf_bumped, data2D_beta_cf, data2D_nu_cf, data2D_rho_cf]
data_collection_bumped = qfCreateDataCollection(data_list_bumped)
sabr_model_bumped = qfCreateSABRModel(sub_model=yc_model, data_collection=data_collection_bumped,build_method_collection=bm_collection)

pv_bumped_cap = qfCreateValueReport(sabr_model_bumped, cap, vpc, "pv")[0][1]

risk_bump_reval_cap = pv_bumped_cap - pv_base_cap
print(f'Bump reval risk is {risk_bump_reval_cap:.10f}.')

df_risk_cap = qfCreateValueReport(sabr_model, cap, vpc, 'firstorderrisk').display()
analytic_risk_cap = df_risk_cap[
    (df_risk_cap["DATA_TYPE"] == risk_data_type)
    & (df_risk_cap["DATA_CONVENTION"] == risk_data_convention)
    & (df_risk_cap["AXIS1"] == risk_expiry)
    & (df_risk_cap["AXIS2"] == risk_tenor)
]['VALUES'].values[0]
analytic_scaled_cap = analytic_risk_cap * bump_size
print(f'Analytic risk is {analytic_scaled_cap}')
print(f"Difference is {risk_bump_reval_cap - analytic_scaled_cap:.10e}.")
# Out:
# Bump reval risk is 0.8860139614.
# Analytic risk is 0.8809531642060138
# Difference is 5.0607971465e-03.
